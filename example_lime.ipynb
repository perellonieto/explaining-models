# %% [markdown]
# Information about the Statlog (Heart) dataset can be found at https://archive.ics.uci.edu/dataset/145/statlog+heart

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
statlog_heart = fetch_ucirepo(id=145)

# %%
statlog_heart.metadata
# Out:
# {'uci_id': 145,
#  'name': 'Statlog (Heart)',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/145/statlog+heart',
#  'data_url': 'https://archive.ics.uci.edu/static/public/145/data.csv',
#  'abstract': 'This dataset is a heart disease database similar to a database already present in the repository (Heart Disease databases) but in a slightly different form',
#  'area': 'Health and Medicine',
#  'tasks': ['Classification'],
#  'characteristics': ['Multivariate'],
#  'num_instances': 270,
#  'num_features': 13,
#  'feature_types': ['Categorical', 'Real'],
#  'demographics': ['Age', 'Sex'],
#  'target_col': ['heart-disease'],
#  'index_col': None,
#  'has_missing_values': 'no',
#  'missing_values_symbol': None,
#  'year_of_dataset_creation': None,
#  'last_updated': 'Fri Feb 09 2024',
#  'dataset_doi': '10.24432/C57303',
#  'creators': [],
#  'intro_paper': None,
#  'additional_info': {'summary': 'Cost Matrix\r\n\r\n_______\t abse  pres\r\nabsence\t 0\t1\r\npresence  5\t0\r\n\r\nwhere the rows represent the true values and the columns the predicted.\r\n',
#   'purpose': None,
#   'funded_by': None,
#   'instances_represent': None,
#   'recommended_data_splits': None,
#   'sensitive_data': None,
#   'preprocessing_description': None,
#   'variable_info': '\r\nAttribute Information:\r\n------------------------\r\n      -- 1. age       \r\n      -- 2. sex       \r\n      -- 3. chest pain type  (4 values)       \r\n      -- 4. resting blood pressure  \r\n      -- 5. serum cholestoral in mg/dl      \r\n      -- 6. fasting blood sugar > 120 mg/dl       \r\n      -- 7. resting electrocardiographic results  (values 0,1,2) \r\n      -- 8. maximum heart rate achieved  \r\n      -- 9. exercise induced angina    \r\n      -- 10. oldpeak = ST depression induced by exercise relative to rest   \r\n      -- 11. the slope of the peak exercise ST segment     \r\n      -- 12. number of major vessels (0-3) colored by flourosopy        \r\n      -- 13.  thal: 3 = normal; 6 = fixed defect; 7 = reversable defect     \r\n\r\nAttributes types\r\n-----------------\r\n\r\nReal: 1,4,5,8,10,12\r\nOrdered:11,\r\nBinary: 2,6,9\r\nNominal:7,3,13\r\n\r\nVariable to be predicted\r\n------------------------\r\nAbsence (1) or presence (2) of heart disease\r\n',
#   'citation': None}}

# %%
statlog_heart.variables
# Out:
#                     name     role         type demographic  \
# 0                    age  Feature   Continuous         Age
# 1                    sex  Feature       Binary         Sex
# 2             chest-pain  Feature  Categorical        None
# 3                rest-bp  Feature   Continuous        None
# 4             serum-chol  Feature   Continuous        None
# 5    fasting-blood-sugar  Feature       Binary        None
# 6   electrocardiographic  Feature  Categorical        None
# 7         max-heart-rate  Feature   Continuous        None
# 8                 angina  Feature       Binary        None
# 9                oldpeak  Feature   Continuous        None
# 10                 slope  Feature      Integer        None
# 11         major-vessels  Feature   Continuous        None
# 12                  thal  Feature  Categorical        None
# 13         heart-disease   Target      Integer        None
#
#                                           description  units missing_values
# 0                                                None   None             no
# 1                                                None   None             no
# 2                                     chest pain type   None             no
# 3                              resting blood pressure   None             no
# 4                                   serum cholesterol  mg/dl             no
# 5                     fasting blood sugar > 120 mg/dl   None             no
# 6                resting electrocardiographic results   None             no
# 7                         maximum heart rate achieved   None             no
# 8                             exercise induced anigna   None             no
# 9   oldpeak = ST depression induced by exercise re...   None             no
# 10           the slope of the peak exercise ST sgment   None             no
# 11  number of major vessels (0-3) colored by fluor...   None             no
# 12  thal: 3 = normal; 6 = fixed defect; 7 = revers...   None             no
# 13                                               None   None             no

# %%
  # data (as pandas dataframes) 
X = statlog_heart.data.features 
y = statlog_heart.data.targets

# %%
X.describe()
# Out:
#               age         sex  chest-pain     rest-bp  serum-chol  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333    0.677778    3.174074  131.344444  249.659259
# std      9.109067    0.468195    0.950090   17.861608   51.686237
# min     29.000000    0.000000    1.000000   94.000000  126.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000
# 50%     55.000000    1.000000    3.000000  130.000000  245.000000
# 75%     61.000000    1.000000    4.000000  140.000000  280.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000
#
#        fasting-blood-sugar  electrocardiographic  max-heart-rate      angina  \
# count           270.000000            270.000000      270.000000  270.000000
# mean              0.148148              1.022222      149.677778    0.329630
# std               0.355906              0.997891       23.165717    0.470952
# min               0.000000              0.000000       71.000000    0.000000
# 25%               0.000000              0.000000      133.000000    0.000000
# 50%               0.000000              2.000000      153.500000    0.000000
# 75%               0.000000              2.000000      166.000000    1.000000
# max               1.000000              2.000000      202.000000    1.000000
#
#          oldpeak       slope  major-vessels        thal
# count  270.00000  270.000000     270.000000  270.000000
# mean     1.05000    1.585185       0.670370    4.696296
# std      1.14521    0.614390       0.943896    1.940659
# min      0.00000    1.000000       0.000000    3.000000
# 25%      0.00000    1.000000       0.000000    3.000000
# 50%      0.80000    2.000000       0.000000    3.000000
# 75%      1.60000    2.000000       1.000000    7.000000
# max      6.20000    3.000000       3.000000    7.000000

# %%
X.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_489fb_row0_col0, #T_489fb_row1_col1, #T_489fb_row2_col2, #T_489fb_row3_col3, #T_489fb_row4_col4, #T_489fb_row5_col5, #T_489fb_row6_col6, #T_489fb_row7_col7, #T_489fb_row8_col8, #T_489fb_row9_col9, #T_489fb_row10_col10, #T_489fb_row11_col11, #T_489fb_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_489fb_row0_col1, #T_489fb_row8_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_489fb_row0_col2, #T_489fb_row0_col3, #T_489fb_row1_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_489fb_row0_col4, #T_489fb_row6_col9 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_489fb_row0_col5, #T_489fb_row5_col1, #T_489fb_row6_col1, #T_489fb_row11_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_489fb_row0_col6, #T_489fb_row5_col4, #T_489fb_row9_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_489fb_row0_col7, #T_489fb_row1_col3, #T_489fb_row1_col4, #T_489fb_row2_col5, #T_489fb_row4_col1, #T_489fb_row7_col0, #T_489fb_row7_col2, #T_489fb_row7_col6, #T_489fb_row7_col8, #T_489fb_row7_col9, #T_489fb_row7_col10, #T_489fb_row7_col11, #T_489fb_row7_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_489fb_row0_col8, #T_489fb_row6_col8, #T_489fb_row10_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_489fb_row0_col9, #T_489fb_row1_col8, #T_489fb_row11_col12 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_489fb_row0_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_489fb_row0_col11 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_489fb_row0_col12 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_489fb_row1_col0, #T_489fb_row4_col3, #T_489fb_row10_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_489fb_row1_col2, #T_489fb_row9_col3 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_489fb_row1_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_489fb_row1_col6, #T_489fb_row12_col7 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_489fb_row1_col7, #T_489fb_row3_col5, #T_489fb_row6_col7, #T_489fb_row8_col4 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_489fb_row1_col9, #T_489fb_row8_col11 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_489fb_row1_col11, #T_489fb_row3_col11, #T_489fb_row4_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_489fb_row1_col12 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_489fb_row2_col0, #T_489fb_row8_col0, #T_489fb_row11_col10 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_489fb_row2_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_489fb_row2_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_489fb_row2_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_489fb_row2_col6, #T_489fb_row6_col5, #T_489fb_row8_col3, #T_489fb_row11_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_489fb_row2_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_489fb_row2_col8 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_489fb_row2_col9, #T_489fb_row3_col10 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_489fb_row2_col10, #T_489fb_row6_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_489fb_row2_col11, #T_489fb_row11_col8 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_489fb_row2_col12, #T_489fb_row9_col11, #T_489fb_row11_col2, #T_489fb_row12_col11 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_489fb_row3_col0, #T_489fb_row12_col10 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_489fb_row3_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_489fb_row3_col2, #T_489fb_row6_col12, #T_489fb_row10_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_489fb_row3_col4, #T_489fb_row4_col2, #T_489fb_row4_col11, #T_489fb_row5_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_489fb_row3_col6, #T_489fb_row11_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_489fb_row3_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_489fb_row3_col8, #T_489fb_row4_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_489fb_row3_col9, #T_489fb_row9_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_489fb_row3_col12, #T_489fb_row5_col11, #T_489fb_row6_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_489fb_row4_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_489fb_row4_col5, #T_489fb_row7_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_489fb_row4_col6, #T_489fb_row4_col12 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_489fb_row4_col7, #T_489fb_row4_col10 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_489fb_row5_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_489fb_row5_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_489fb_row5_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_489fb_row5_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_489fb_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_489fb_row5_col8, #T_489fb_row11_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_489fb_row5_col9, #T_489fb_row5_col12, #T_489fb_row11_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_489fb_row6_col2, #T_489fb_row6_col11 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_489fb_row6_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_489fb_row6_col10 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_489fb_row7_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_489fb_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_489fb_row7_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_489fb_row8_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_489fb_row8_col2, #T_489fb_row12_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_489fb_row8_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_489fb_row8_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_489fb_row8_col9, #T_489fb_row8_col10, #T_489fb_row10_col8 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_489fb_row8_col12, #T_489fb_row9_col12 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_489fb_row9_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_489fb_row9_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_489fb_row9_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_489fb_row9_col6, #T_489fb_row12_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_489fb_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_489fb_row9_col8 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_489fb_row9_col10 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_489fb_row10_col0 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_489fb_row10_col3, #T_489fb_row12_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_489fb_row10_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_489fb_row10_col5 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_489fb_row10_col7 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_489fb_row10_col9 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_489fb_row10_col11 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_489fb_row10_col12 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_489fb_row11_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_489fb_row11_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_489fb_row11_col9 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_489fb_row12_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_489fb_row12_col1 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_489fb_row12_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_489fb_row12_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_489fb_row12_col6 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_489fb_row12_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# </style>
# <table id="T_489fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_489fb_level0_col0" class="col_heading level0 col0" >age</th

# %%
y.describe()
# Out:
#        heart-disease
# count     270.000000
# mean        1.444444
# std         0.497827
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000

# %%
from sklearn.model_selection import train_test_split

# TODO : add seed here
import numpy
numpy.random.seed(42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.describe()
# Out:
#               age         sex  chest-pain     rest-bp  serum-chol  \
# count  189.000000  189.000000  189.000000  189.000000  189.000000
# mean    54.751323    0.693122    3.211640  131.809524  251.529101
# std      9.132393    0.462423    0.966278   17.952233   52.554890
# min     29.000000    0.000000    1.000000   94.000000  141.000000
# 25%     48.000000    0.000000    3.000000  120.000000  215.000000
# 50%     56.000000    1.000000    4.000000  130.000000  244.000000
# 75%     62.000000    1.000000    4.000000  140.000000  282.000000
# max     74.000000    1.000000    4.000000  200.000000  564.000000
#
#        fasting-blood-sugar  electrocardiographic  max-heart-rate      angina  \
# count           189.000000            189.000000      189.000000  189.000000
# mean              0.137566              1.042328      149.317460    0.370370
# std               0.345359              0.999099       22.877443    0.484186
# min               0.000000              0.000000       88.000000    0.000000
# 25%               0.000000              0.000000      132.000000    0.000000
# 50%               0.000000              2.000000      154.000000    0.000000
# 75%               0.000000              2.000000      166.000000    1.000000
# max               1.000000              2.000000      202.000000    1.000000
#
#           oldpeak       slope  major-vessels        thal
# count  189.000000  189.000000     189.000000  189.000000
# mean     1.155556    1.608466       0.698413    4.783069
# std      1.195707    0.614655       0.967035    1.948957
# min      0.000000    1.000000       0.000000    3.000000
# 25%      0.000000    1.000000       0.000000    3.000000
# 50%      1.000000    2.000000       0.000000    3.000000
# 75%      1.800000    2.000000       1.000000    7.000000
# max      6.200000    3.000000       3.000000    7.000000

# %%
X_test.describe()
# Out:
#              age        sex  chest-pain     rest-bp  serum-chol  \
# count  81.000000  81.000000   81.000000   81.000000   81.000000
# mean   53.691358   0.641975    3.086420  130.259259  245.296296
# std     9.067307   0.482407    0.911009   17.711421   49.644094
# min    35.000000   0.000000    1.000000   94.000000  126.000000
# 25%    46.000000   0.000000    3.000000  120.000000  208.000000
# 50%    54.000000   1.000000    3.000000  130.000000  249.000000
# 75%    59.000000   1.000000    4.000000  140.000000  273.000000
# max    77.000000   1.000000    4.000000  192.000000  407.000000
#
#        fasting-blood-sugar  electrocardiographic  max-heart-rate     angina  \
# count            81.000000             81.000000       81.000000  81.000000
# mean              0.172840              0.975309      150.518519   0.234568
# std               0.380464              0.999691       23.948440   0.426369
# min               0.000000              0.000000       71.000000   0.000000
# 25%               0.000000              0.000000      138.000000   0.000000
# 50%               0.000000              0.000000      153.000000   0.000000
# 75%               0.000000              2.000000      167.000000   0.000000
# max               1.000000              2.000000      195.000000   1.000000
#
#          oldpeak      slope  major-vessels       thal
# count  81.000000  81.000000      81.000000  81.000000
# mean    0.803704   1.530864       0.604938   4.493827
# std     0.981000   0.614134       0.889930   1.917834
# min     0.000000   1.000000       0.000000   3.000000
# 25%     0.000000   1.000000       0.000000   3.000000
# 50%     0.500000   1.000000       0.000000   3.000000
# 75%     1.400000   2.000000       1.000000   7.000000
# max     4.000000   3.000000       3.000000   7.000000

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

clf.fit(X_train, y_train)
# Out:
# /home/mp15688/git/explaining-models/venv/lib/python3.10/site-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_train.shape
# Out:
# (189, 1)
