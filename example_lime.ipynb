# %% [markdown]
# # Explaining models using LIME
#
# Adapted by Miquel Perello-Nieto, based on a R notebook by Telmo Silva Filho
#
#
# # Introduction
#
# In this practical, we will learn how to explain models using the LIME package. For starters, we will use the Statlog (heart)) dataset. Information about the Statlog (Heart) dataset can be found at https://archive.ics.uci.edu/dataset/145/statlog+heart

# %%
import pandas
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
statlog_heart = fetch_ucirepo(id=145)

# %%
statlog_heart.metadata
# Out:
# {'uci_id': 145,
#  'name': 'Statlog (Heart)',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/145/statlog+heart',
#  'data_url': 'https://archive.ics.uci.edu/static/public/145/data.csv',
#  'abstract': 'This dataset is a heart disease database similar to a database already present in the repository (Heart Disease databases) but in a slightly different form',
#  'area': 'Health and Medicine',
#  'tasks': ['Classification'],
#  'characteristics': ['Multivariate'],
#  'num_instances': 270,
#  'num_features': 13,
#  'feature_types': ['Categorical', 'Real'],
#  'demographics': ['Age', 'Sex'],
#  'target_col': ['heart-disease'],
#  'index_col': None,
#  'has_missing_values': 'no',
#  'missing_values_symbol': None,
#  'year_of_dataset_creation': None,
#  'last_updated': 'Fri Feb 09 2024',
#  'dataset_doi': '10.24432/C57303',
#  'creators': [],
#  'intro_paper': None,
# ...

# %%
class_names = ['Absence', 'Presence']
statlog_heart.variables
# Out:
#                     name     role         type demographic  \
# 0                    age  Feature   Continuous         Age
# 1                    sex  Feature       Binary         Sex
# 2             chest-pain  Feature  Categorical        None
# 3                rest-bp  Feature   Continuous        None
# 4             serum-chol  Feature   Continuous        None
# 5    fasting-blood-sugar  Feature       Binary        None
# 6   electrocardiographic  Feature  Categorical        None
# 7         max-heart-rate  Feature   Continuous        None
# 8                 angina  Feature       Binary        None
# 9                oldpeak  Feature   Continuous        None
# 10                 slope  Feature      Integer        None
# 11         major-vessels  Feature   Continuous        None
# 12                  thal  Feature  Categorical        None
# 13         heart-disease   Target      Integer        None
#
#                                           description  units missing_values
# ...

# %%
  # data (as pandas dataframes) 
X = statlog_heart.data.features 
y = statlog_heart.data.targets

# %%
X.head()
# Out:
#     age  sex  chest-pain  rest-bp  serum-chol  fasting-blood-sugar  \
# 0  70.0  1.0         4.0    130.0       322.0                  0.0
# 1  67.0  0.0         3.0    115.0       564.0                  0.0
# 2  57.0  1.0         2.0    124.0       261.0                  0.0
# 3  64.0  1.0         4.0    128.0       263.0                  0.0
# 4  74.0  0.0         2.0    120.0       269.0                  0.0
#
#    electrocardiographic  max-heart-rate  angina  oldpeak  slope  \
# 0                   2.0           109.0     0.0      2.4    2.0
# 1                   2.0           160.0     0.0      1.6    2.0
# 2                   0.0           141.0     0.0      0.3    1.0
# 3                   0.0           105.0     1.0      0.2    2.0
# 4                   2.0           121.0     1.0      0.2    1.0
#
#    major-vessels  thal
# 0            3.0   3.0
# 1            0.0   7.0
# 2            0.0   7.0
# 3            1.0   7.0
# 4            1.0   3.0

# %%
X.describe()
# Out:
#               age         sex  chest-pain     rest-bp  serum-chol  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333    0.677778    3.174074  131.344444  249.659259
# std      9.109067    0.468195    0.950090   17.861608   51.686237
# min     29.000000    0.000000    1.000000   94.000000  126.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000
# 50%     55.000000    1.000000    3.000000  130.000000  245.000000
# 75%     61.000000    1.000000    4.000000  140.000000  280.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000
#
#        fasting-blood-sugar  electrocardiographic  max-heart-rate      angina  \
# count           270.000000            270.000000      270.000000  270.000000
# mean              0.148148              1.022222      149.677778    0.329630
# std               0.355906              0.997891       23.165717    0.470952
# ...

# %%
X.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_78905_row0_col0, #T_78905_row1_col1, #T_78905_row2_col2, #T_78905_row3_col3, #T_78905_row4_col4, #T_78905_row5_col5, #T_78905_row6_col6, #T_78905_row7_col7, #T_78905_row8_col8, #T_78905_row9_col9, #T_78905_row10_col10, #T_78905_row11_col11, #T_78905_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_78905_row0_col1, #T_78905_row8_col5 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_78905_row0_col2, #T_78905_row0_col3, #T_78905_row1_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_78905_row0_col4, #T_78905_row6_col9 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_78905_row0_col5, #T_78905_row5_col1, #T_78905_row6_col1, #T_78905_row11_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_78905_row0_col6, #T_78905_row5_col4, #T_78905_row9_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# ...

# %%
import seaborn
feature_subset = ['age','sex', 'chest-pain', 'rest-bp', 'serum-chol', 'max-heart-rate', 'oldpeak']
seaborn.pairplot(pandas.concat([X[feature_subset], y], axis=1), hue='heart-disease')

# %%
y.describe()
# Out:
#        heart-disease
# count     270.000000
# mean        1.444444
# std         0.497827
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000

# %%
from sklearn.model_selection import train_test_split

# TODO : add seed here
import numpy
numpy.random.seed(42)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.describe()
# Out:
#               age         sex  chest-pain     rest-bp  serum-chol  \
# count  189.000000  189.000000  189.000000  189.000000  189.000000
# mean    54.751323    0.693122    3.211640  131.809524  251.529101
# std      9.132393    0.462423    0.966278   17.952233   52.554890
# min     29.000000    0.000000    1.000000   94.000000  141.000000
# 25%     48.000000    0.000000    3.000000  120.000000  215.000000
# 50%     56.000000    1.000000    4.000000  130.000000  244.000000
# 75%     62.000000    1.000000    4.000000  140.000000  282.000000
# max     74.000000    1.000000    4.000000  200.000000  564.000000
#
#        fasting-blood-sugar  electrocardiographic  max-heart-rate      angina  \
# count           189.000000            189.000000      189.000000  189.000000
# mean              0.137566              1.042328      149.317460    0.370370
# std               0.345359              0.999099       22.877443    0.484186
# ...

# %%
X_test.describe()
# Out:
#              age        sex  chest-pain     rest-bp  serum-chol  \
# count  81.000000  81.000000   81.000000   81.000000   81.000000
# mean   53.691358   0.641975    3.086420  130.259259  245.296296
# std     9.067307   0.482407    0.911009   17.711421   49.644094
# min    35.000000   0.000000    1.000000   94.000000  126.000000
# 25%    46.000000   0.000000    3.000000  120.000000  208.000000
# 50%    54.000000   1.000000    3.000000  130.000000  249.000000
# 75%    59.000000   1.000000    4.000000  140.000000  273.000000
# max    77.000000   1.000000    4.000000  192.000000  407.000000
#
#        fasting-blood-sugar  electrocardiographic  max-heart-rate     angina  \
# count            81.000000             81.000000       81.000000  81.000000
# mean              0.172840              0.975309      150.518519   0.234568
# std               0.380464              0.999691       23.948440   0.426369
# min               0.000000              0.000000       71.000000   0.000000
# ...

# %% [markdown]
# # Fitting a model
#
# We will train a random forest classifier.

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier()

clf.fit(X_train, y_train.values.reshape(-1))
# Out:
# RandomForestClassifier()

# %%
print(f'Training accuracy {numpy.mean(clf.predict(X_train) == y_train.values.reshape(-1))}')
print(f'Test accuracy {numpy.mean(clf.predict(X_test) == y_test.values.reshape(-1))}')
# Out:
# Training accuracy 1.0
# Test accuracy 0.8271604938271605

# %% [markdown]
# # Assessing the feature importance
#
# # Question 1
#
# Find the feature importances of the random forest.

# %%
forest_importances = pandas.Series(clf.feature_importances_, index=X.columns)
forest_importances.plot.bar(ylabel='Mean decrease in impurity')
# Out:
# <Axes: ylabel='Mean decrease in impurity'>

# %%
std = numpy.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)
forest_importances.plot.bar(yerr=std)
# Out:
# <Axes: >

# %%
new_order = numpy.argsort(-clf.feature_importances_)
sorted_forest_importances = pandas.Series(clf.feature_importances_[new_order], index=X.columns[new_order])

std = numpy.std([tree.feature_importances_[new_order] for tree in clf.estimators_], axis=0)
sorted_forest_importances.plot.bar(yerr=std)
# Out:
# <Axes: >

# %% [markdown]
# # Permutation Feature Importance
#
# We can calculate the feature importance with other evaluation metrics. In this case, how does the accuracy change per each feature.

# %%
from sklearn.inspection import permutation_importance

results = permutation_importance(clf, X_test, y_test, scoring='accuracy', n_repeats=50, random_state=42)

forest_importances = pandas.Series(results.importances_mean, index=X_test.columns)
forest_importances.plot.bar(yerr=results.importances_std, ylabel='Mean accuracy decrease')
# Out:
# <Axes: ylabel='Mean accuracy decrease'>

# %% [markdown]
# # Using LIME to explain the feature importance

# %%
from lime.lime_tabular import LimeTabularExplainer

explainer = LimeTabularExplainer(X_train.values, feature_names=X_train.columns, 
                                 class_names=class_names, verbose=True)

# %%
instance_id = 0
print(X_test.iloc[instance_id])
exp = explainer.explain_instance(X_test.iloc[instance_id], clf.predict_proba)
# Out:
# age                      57.0
# sex                       1.0
# chest-pain                3.0
# rest-bp                 128.0
# serum-chol              229.0
# fasting-blood-sugar       0.0
# electrocardiographic      2.0
# max-heart-rate          150.0
# angina                    0.0
# oldpeak                   0.4
# slope                     2.0
# major-vessels             1.0
# thal                      7.0
# Name: 30, dtype: float64
# Intercept 0.39497646169065537
# Prediction_local [0.55705703]
# Right: 0.48
# /home/mp15688/git/explaining-models/venv/lib/python3.10/site-packages/lime/discretize.py:110: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ret[feature] = int(self.lambdas[feature](ret[feature]))
# ...

# %%
exp.show_in_notebook()
# Out:
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# ...

# %%
from IPython.display import display, HTML
display(HTML(statlog_heart.variables.query('name == "thal"').to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>role</th>
#       <th>type</th>
#       <th>demographic</th>
#       <th>description</th>
#       <th>units</th>
#       <th>missing_values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>12</th>
#       <td>thal</td>
#       <td>Feature</td>
#       <td>Categorical</td>
#       <td>None</td>
#       <td>thal: 3 = normal; 6 = fixed defect; 7 = reversable defect</td>
#       <td>None</td>
#       <td>no</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Question 2
#
# What features tend to contribute more when the model assigns instances to each class? Try explaining some instances assigned to each class (see the Label attribute in the plot produced by LIME). Then see if certain features show up more for each class.

# %% [markdown]
# # Question 3
#
# Do features considered important by the Random Forest model appear as important in the LIME explanations?

# %% [markdown]
# # Question 4
#
# For instances of the same class, how different are the explanations when the model correctly or incorrectly predicts their class?

# %% [markdown]
# # Question 5
#
# Now try the different models you have seen in previous classes. Do the explanations show that other features are important for different models?
